# %%
# CREATE COMBINED REVERSED IMAGE
import os
from PIL import Image, ImageDraw, ImageFont, ImageOps

def add_border(image, border_size, border_color):
    return ImageOps.expand(image, border=border_size, fill=border_color)

def draw_centered_text(draw, text, image_width, start_x, y_position, font):
    # text_width, text_height = draw.textsize(text, font=font)
    bbox = draw.textbbox((0, 0), text, font=font)
    text_width = bbox[2] - bbox[0]
    x_position = start_x + (image_width - text_width) // 2
    draw.text((x_position, y_position), text, fill="black", font=font)

def create_combined_image(image_paths, output_path):
    premise_image = Image.open(image_paths['premise'])
    hypothesis1_image = Image.open(image_paths['hypothesis1'])
    hypothesis2_image = Image.open(image_paths['hypothesis2'])

    border_color = "black"
    background_color = "white"
    border_size = 5
    extra_space = 50  # Additional space between images


    premise_image = add_border(premise_image, border_size, border_color)
    hypothesis1_image = add_border(hypothesis1_image, border_size, border_color)
    hypothesis2_image = add_border(hypothesis2_image, border_size, border_color)

    width, height = premise_image.size

    total_width = width * 3 + border_size * 2 * 3 + extra_space * 2
    total_height = height + 150
    new_image = Image.new("RGB", (total_width, total_height), background_color)

    new_image.paste(premise_image, (border_size, 150))
    new_image.paste(hypothesis1_image, (width + 2 * border_size + extra_space, 150))
    new_image.paste(hypothesis2_image, (2 * width + 3 * border_size + 2 * extra_space, 150))

    draw = ImageDraw.Draw(new_image)
    font_size = 70
    font = ImageFont.truetype("n019004l.pfb", font_size)

    title_y_position = 70

    draw_centered_text(draw, "Premise", width, border_size, title_y_position, font)
    draw_centered_text(draw, "Hypothesis 1", width, width + 2 * border_size + extra_space, title_y_position, font)
    draw_centered_text(draw, "Hypothesis 2", width, 2 * width + 3 * border_size + 2 * extra_space, title_y_position, font)

    new_image.save(output_path)

def process_directory(root_folder):
    for subdir, dirs, files in os.walk(root_folder):
        # We expect three specific image files in each sub-sub-folder
        image_files = {'premise': None, 'hypothesis1': None, 'hypothesis2': None}
        for filename in files:
            if 'premise' in filename.lower():
                image_files['premise'] = os.path.join(subdir, filename)
            elif 'hypothesis1' in filename.lower():
                image_files['hypothesis1'] = os.path.join(subdir, filename)
            elif 'hypothesis2' in filename.lower():
                image_files['hypothesis2'] = os.path.join(subdir, filename)
        
        # If all three images are found, create the combined image
        if all(image_files.values()):
            output_path = os.path.join(subdir, 'combined_image.png')
            create_combined_image(image_files, output_path)
            print(f"Created combined image at: {output_path}")

process_directory('/home/student/VLM image dataset')
# Out:
# Created combined image at: /home/student/VLM image dataset/313/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/313/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/313/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/39/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/39/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/39/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/357/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/357/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/357/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/357/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/357/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/38/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/38/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/38/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/311/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/311/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/311/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/86/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/86/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/86/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/86/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/118/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/118/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/118/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/118/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/4/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/4/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/4/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/37/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/37/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/37/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/53/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/53/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/53/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/1/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/1/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/1/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/58/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/58/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/58/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/189/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/189/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/189/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/99/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/99/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/99/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/11/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/11/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/11/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/351/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/351/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/351/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/351/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/351/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/298/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/298/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/298/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/87/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/87/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/87/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/10/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/10/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/10/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/50/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/50/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/50/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/22/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/22/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/22/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/8/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/8/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/8/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/8/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/3/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/3/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/3/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/21/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/21/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/21/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/355/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/355/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/355/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/355/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/355/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/47/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/47/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/47/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/47/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/354/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/354/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/354/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/354/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/354/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/141/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/141/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/141/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/84/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/84/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/84/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/84/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/56/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/56/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/56/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/30/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/30/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/30/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/30/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/344/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/344/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/344/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/20/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/20/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/20/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/199/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/199/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/199/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/310/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/310/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/310/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/276/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/276/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/276/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/23/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/23/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/23/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/149/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/149/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/149/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/352/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/352/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/352/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/352/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/352/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/205/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/205/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/205/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/358/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/358/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/358/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/358/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/358/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/63/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/63/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/63/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/63/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/345/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/345/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/345/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/54/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/54/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/54/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/16/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/16/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/16/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/36/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/36/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/36/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/356/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/356/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/356/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/356/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/356/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/51/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/51/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/51/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/51/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/172/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/172/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/172/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/12/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/12/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/12/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/7/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/7/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/7/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/136/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/136/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/136/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/28/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/28/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/28/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/314/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/314/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/314/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/248/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/248/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/248/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/78/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/78/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/78/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/312/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/312/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/312/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/353/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/353/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/353/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/353/photorialistic/combined_image.png
# Created combined image at: /home/student/VLM image dataset/353/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/320/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/320/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/320/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/184/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/184/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/184/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/309/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/309/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/309/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/24/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/24/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/24/photographed/combined_image.png
# Created combined image at: /home/student/VLM image dataset/24/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/315/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/315/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/315/anime/combined_image.png
# Created combined image at: /home/student/VLM image dataset/25/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/34/sketched/combined_image.png
# Created combined image at: /home/student/VLM image dataset/34/paper cut/combined_image.png
# Created combined image at: /home/student/VLM image dataset/34/anime/combined_image.png

# %%
# CREATE COMBINED REVERSED IMAGE
import os
from PIL import Image, ImageDraw, ImageFont, ImageOps

def add_border(image, border_size, border_color):
    return ImageOps.expand(image, border=border_size, fill=border_color)

def draw_centered_text(draw, text, image_width, start_x, y_position, font):
    # text_width, text_height = draw.textsize(text, font=font)
    bbox = draw.textbbox((0, 0), text, font=font)
    text_width = bbox[2] - bbox[0]
    x_position = start_x + (image_width - text_width) // 2
    draw.text((x_position, y_position), text, fill="black", font=font)

def create_combined_image(image_paths, output_path):
    premise_image = Image.open(image_paths['premise'])
    hypothesis1_image = Image.open(image_paths['hypothesis1'])
    hypothesis2_image = Image.open(image_paths['hypothesis2'])

    border_color = "black"
    background_color = "white"
    border_size = 5
    extra_space = 50  # Additional space between images


    premise_image = add_border(premise_image, border_size, border_color)
    hypothesis1_image = add_border(hypothesis1_image, border_size, border_color)
    hypothesis2_image = add_border(hypothesis2_image, border_size, border_color)

    width, height = premise_image.size

    total_width = width * 3 + border_size * 2 * 3 + extra_space * 2
    total_height = height + 150
    new_image = Image.new("RGB", (total_width, total_height), background_color)

    new_image.paste(premise_image, (border_size, 150))
    new_image.paste(hypothesis1_image, (width + 2 * border_size + extra_space, 150))
    new_image.paste(hypothesis2_image, (2 * width + 3 * border_size + 2 * extra_space, 150))

    draw = ImageDraw.Draw(new_image)
    font_size = 70
    font = ImageFont.truetype("n019004l.pfb", font_size)

    title_y_position = 70

    draw_centered_text(draw, "Premise", width, border_size, title_y_position, font)
    draw_centered_text(draw, "Hypothesis 1", width, width + 2 * border_size + extra_space, title_y_position, font)
    draw_centered_text(draw, "Hypothesis 2", width, 2 * width + 3 * border_size + 2 * extra_space, title_y_position, font)

    new_image.save(output_path)

def process_directory(root_folder):
    for subdir, dirs, files in os.walk(root_folder):
        # We expect three specific image files in each sub-sub-folder
        image_files = {'premise': None, 'hypothesis1': None, 'hypothesis2': None}
        for filename in files:
            if 'premise' in filename.lower():
                image_files['premise'] = os.path.join(subdir, filename)
            elif 'hypothesis1' in filename.lower():
                image_files['hypothesis2'] = os.path.join(subdir, filename)
            elif 'hypothesis2' in filename.lower():
                image_files['hypothesis1'] = os.path.join(subdir, filename)
        
        # If all three images are found, create the combined image
        if all(image_files.values()):
            output_path = os.path.join(subdir, 'combined_image_reversed.png')
            create_combined_image(image_files, output_path)
            print(f"Created combined image at: {output_path}")

process_directory('/home/student/VLM image dataset')
# Out:
# Created combined image at: /home/student/VLM image dataset/313/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/313/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/313/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/39/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/39/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/39/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/357/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/357/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/357/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/357/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/357/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/38/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/38/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/38/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/311/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/311/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/311/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/86/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/86/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/86/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/86/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/118/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/118/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/118/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/118/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/4/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/4/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/4/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/37/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/37/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/37/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/53/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/53/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/53/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/1/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/1/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/1/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/58/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/58/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/58/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/189/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/189/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/189/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/99/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/99/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/99/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/11/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/11/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/11/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/351/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/351/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/351/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/351/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/351/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/298/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/298/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/298/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/87/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/87/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/87/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/10/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/10/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/10/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/50/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/50/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/50/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/22/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/22/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/22/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/8/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/8/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/8/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/8/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/3/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/3/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/3/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/21/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/21/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/21/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/355/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/355/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/355/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/355/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/355/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/47/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/47/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/47/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/47/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/354/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/354/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/354/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/354/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/354/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/141/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/141/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/141/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/84/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/84/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/84/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/84/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/56/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/56/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/56/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/30/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/30/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/30/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/30/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/344/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/344/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/344/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/20/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/20/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/20/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/199/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/199/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/199/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/310/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/310/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/310/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/276/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/276/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/276/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/23/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/23/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/23/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/149/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/149/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/149/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/352/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/352/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/352/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/352/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/352/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/205/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/205/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/205/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/358/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/358/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/358/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/358/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/358/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/63/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/63/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/63/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/63/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/345/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/345/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/345/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/54/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/54/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/54/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/16/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/16/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/16/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/36/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/36/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/36/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/356/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/356/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/356/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/356/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/356/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/51/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/51/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/51/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/51/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/172/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/172/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/172/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/12/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/12/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/12/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/7/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/7/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/7/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/136/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/136/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/136/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/28/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/28/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/28/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/314/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/314/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/314/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/248/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/248/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/248/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/78/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/78/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/78/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/312/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/312/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/312/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/353/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/353/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/353/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/353/photorialistic/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/353/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/320/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/320/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/320/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/184/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/184/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/184/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/309/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/309/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/309/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/24/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/24/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/24/photographed/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/24/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/315/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/315/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/315/anime/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/25/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/34/sketched/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/34/paper cut/combined_image_reversed.png
# Created combined image at: /home/student/VLM image dataset/34/anime/combined_image_reversed.png
